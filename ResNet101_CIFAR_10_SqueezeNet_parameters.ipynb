# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.models import resnet101

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from cosine_annealing_warmup import CosineAnnealingWarmupRestarts

from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

import pathlib
import os

# %%
model = resnet101(pretrained=False, num_classes=10)

model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
model.maxpool = nn.Identity()
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
class Fire(nn.Module):

    def __init__(self, inplanes, squeeze_planes,
                 expand1x1_planes, expand3x3_planes, stride = 1):
        super(Fire, self).__init__()
        self.inplanes = inplanes
        self.squeeze = nn.Conv2d(inplanes, squeeze_planes, kernel_size=1)
        self.squeeze_activation = nn.ReLU(inplace=True)
        self.expand1x1 = nn.Conv2d(squeeze_planes, expand1x1_planes,
                                   kernel_size=1, stride = stride)
        self.expand1x1_activation = nn.ReLU(inplace=True)
        self.expand3x3 = nn.Conv2d(squeeze_planes, expand3x3_planes,
                                   kernel_size=3, padding=1, stride = stride)
        self.expand3x3_activation = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.squeeze_activation(self.squeeze(x))
        return torch.cat([
            self.expand1x1_activation(self.expand1x1(x)),
            self.expand3x3_activation(self.expand3x3(x))
        ], 1)

# %%
model.layer1[0] = Fire(64, 64, 128, 128)
model.layer1[1] = Fire(256, 64, 128, 128)
model.layer1[2] = Fire(256, 64, 128, 128)
model.layer2[0] = Fire(256, 128, 256, 256, 2)
model.layer2[1] = Fire(512, 128, 256, 256)
model.layer2[2] = Fire(512, 128, 256, 256)
model.layer2[3] = Fire(512, 128, 256, 256)
model.layer3[0] = Fire(512, 256, 512, 512, 2)
model.layer3[1] = Fire(1024, 256, 512, 512)
model.layer3[2] = Fire(1024, 256, 512, 512)
model.layer3[3] = Fire(1024, 256, 512, 512)
model.layer3[4] = Fire(1024, 256, 512, 512)
model.layer3[5] = Fire(1024, 256, 512, 512)
model.layer3[6] = Fire(1024, 256, 512, 512)
model.layer3[7] = Fire(1024, 256, 512, 512)
model.layer3[8] = Fire(1024, 256, 512, 512)
model.layer3[9] = Fire(1024, 256, 512, 512)
model.layer3[10] = Fire(1024, 256, 512, 512)
model.layer3[11] = Fire(1024, 256, 512, 512)
model.layer3[12] = Fire(1024, 256, 512, 512)
model.layer3[13] = Fire(1024, 256, 512, 512)
model.layer3[14] = Fire(1024, 256, 512, 512)
model.layer3[15] = Fire(1024, 256, 512, 512)
model.layer3[16] = Fire(1024, 256, 512, 512)
model.layer3[17] = Fire(1024, 256, 512, 512)
model.layer3[18] = Fire(1024, 256, 512, 512)
model.layer3[19] = Fire(1024, 256, 512, 512)
model.layer3[20] = Fire(1024, 256, 512, 512)
model.layer3[21] = Fire(1024, 256, 512, 512)
model.layer3[22] = Fire(1024, 256, 512, 512)
model.layer4[0] = Fire(1024, 512, 1024, 1024, 2)
model.layer4[1] = Fire(2048, 512, 1024, 1024)
model.layer4[2] = Fire(2048, 512, 1024, 1024)

# %%
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): Identity()
#   (layer1): Sequential(
#     (0): Fire(
#       (squeeze): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (1): Fire(
#       (squeeze): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (2): Fire(
#       (squeeze): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Fire(
#       (squeeze): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (1): Fire(
#       (squeeze): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (2): Fire(
#       (squeeze): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (3): Fire(
#       (squeeze): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Fire(
#       (squeeze): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (1): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (2): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (3): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (7): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (12): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (13): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (14): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (15): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (16): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (17): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (18): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (19): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (20): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (21): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (22): Fire(
#       (squeeze): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Fire(
#       (squeeze): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (1): Fire(
#       (squeeze): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (2): Fire(
#       (squeeze): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

count_parameters(model)

pytorch_total_params = sum(p.numel() for p in model.parameters())
print("Total Params: ", pytorch_total_params)
# Out:
# +----------------------------+------------+
# |          Modules           | Parameters |
# +----------------------------+------------+
# |        conv1.weight        |    1728    |
# |         bn1.weight         |     64     |
# |          bn1.bias          |     64     |
# |  layer1.0.squeeze.weight   |    4096    |
# |   layer1.0.squeeze.bias    |     64     |
# | layer1.0.expand1x1.weight  |    8192    |
# |  layer1.0.expand1x1.bias   |    128     |
# | layer1.0.expand3x3.weight  |   73728    |
# |  layer1.0.expand3x3.bias   |    128     |
# |  layer1.1.squeeze.weight   |   16384    |
# |   layer1.1.squeeze.bias    |     64     |
# | layer1.1.expand1x1.weight  |    8192    |
# |  layer1.1.expand1x1.bias   |    128     |
# | layer1.1.expand3x3.weight  |   73728    |
# |  layer1.1.expand3x3.bias   |    128     |
# |  layer1.2.squeeze.weight   |   16384    |
# |   layer1.2.squeeze.bias    |     64     |
# | layer1.2.expand1x1.weight  |    8192    |
# |  layer1.2.expand1x1.bias   |    128     |
# | layer1.2.expand3x3.weight  |   73728    |
# |  layer1.2.expand3x3.bias   |    128     |
# |  layer2.0.squeeze.weight   |   32768    |
# |   layer2.0.squeeze.bias    |    128     |
# | layer2.0.expand1x1.weight  |   32768    |
# |  layer2.0.expand1x1.bias   |    256     |
# | layer2.0.expand3x3.weight  |   294912   |
# |  layer2.0.expand3x3.bias   |    256     |
# |  layer2.1.squeeze.weight   |   65536    |
# |   layer2.1.squeeze.bias    |    128     |
# | layer2.1.expand1x1.weight  |   32768    |
# |  layer2.1.expand1x1.bias   |    256     |
# | layer2.1.expand3x3.weight  |   294912   |
# |  layer2.1.expand3x3.bias   |    256     |
# |  layer2.2.squeeze.weight   |   65536    |
# |   layer2.2.squeeze.bias    |    128     |
# | layer2.2.expand1x1.weight  |   32768    |
# |  layer2.2.expand1x1.bias   |    256     |
# | layer2.2.expand3x3.weight  |   294912   |
# |  layer2.2.expand3x3.bias   |    256     |
# |  layer2.3.squeeze.weight   |   65536    |
# |   layer2.3.squeeze.bias    |    128     |
# | layer2.3.expand1x1.weight  |   32768    |
# |  layer2.3.expand1x1.bias   |    256     |
# | layer2.3.expand3x3.weight  |   294912   |
# |  layer2.3.expand3x3.bias   |    256     |
# |  layer3.0.squeeze.weight   |   131072   |
# |   layer3.0.squeeze.bias    |    256     |
# | layer3.0.expand1x1.weight  |   131072   |
# |  layer3.0.expand1x1.bias   |    512     |
# | layer3.0.expand3x3.weight  |  1179648   |
# |  layer3.0.expand3x3.bias   |    512     |
# |  layer3.1.squeeze.weight   |   262144   |
# |   layer3.1.squeeze.bias    |    256     |
# | layer3.1.expand1x1.weight  |   131072   |
# |  layer3.1.expand1x1.bias   |    512     |
# | layer3.1.expand3x3.weight  |  1179648   |
# |  layer3.1.expand3x3.bias   |    512     |
# |  layer3.2.squeeze.weight   |   262144   |
# |   layer3.2.squeeze.bias    |    256     |
# | layer3.2.expand1x1.weight  |   131072   |
# |  layer3.2.expand1x1.bias   |    512     |
# | layer3.2.expand3x3.weight  |  1179648   |
# |  layer3.2.expand3x3.bias   |    512     |
# |  layer3.3.squeeze.weight   |   262144   |
# |   layer3.3.squeeze.bias    |    256     |
# | layer3.3.expand1x1.weight  |   131072   |
# |  layer3.3.expand1x1.bias   |    512     |
# | layer3.3.expand3x3.weight  |  1179648   |
# |  layer3.3.expand3x3.bias   |    512     |
# |  layer3.4.squeeze.weight   |   262144   |
# |   layer3.4.squeeze.bias    |    256     |
# | layer3.4.expand1x1.weight  |   131072   |
# |  layer3.4.expand1x1.bias   |    512     |
# | layer3.4.expand3x3.weight  |  1179648   |
# |  layer3.4.expand3x3.bias   |    512     |
# |  layer3.5.squeeze.weight   |   262144   |
# |   layer3.5.squeeze.bias    |    256     |
# | layer3.5.expand1x1.weight  |   131072   |
# |  layer3.5.expand1x1.bias   |    512     |
# | layer3.5.expand3x3.weight  |  1179648   |
# |  layer3.5.expand3x3.bias   |    512     |
# |  layer3.6.squeeze.weight   |   262144   |
# |   layer3.6.squeeze.bias    |    256     |
# | layer3.6.expand1x1.weight  |   131072   |
# |  layer3.6.expand1x1.bias   |    512     |
# | layer3.6.expand3x3.weight  |  1179648   |
# |  layer3.6.expand3x3.bias   |    512     |
# |  layer3.7.squeeze.weight   |   262144   |
# |   layer3.7.squeeze.bias    |    256     |
# | layer3.7.expand1x1.weight  |   131072   |
# |  layer3.7.expand1x1.bias   |    512     |
# | layer3.7.expand3x3.weight  |  1179648   |
# |  layer3.7.expand3x3.bias   |    512     |
# |  layer3.8.squeeze.weight   |   262144   |
# |   layer3.8.squeeze.bias    |    256     |
# | layer3.8.expand1x1.weight  |   131072   |
# |  layer3.8.expand1x1.bias   |    512     |
# | layer3.8.expand3x3.weight  |  1179648   |
# |  layer3.8.expand3x3.bias   |    512     |
# |  layer3.9.squeeze.weight   |   262144   |
# |   layer3.9.squeeze.bias    |    256     |
# | layer3.9.expand1x1.weight  |   131072   |
# |  layer3.9.expand1x1.bias   |    512     |
# | layer3.9.expand3x3.weight  |  1179648   |
# |  layer3.9.expand3x3.bias   |    512     |
# |  layer3.10.squeeze.weight  |   262144   |
# |   layer3.10.squeeze.bias   |    256     |
# | layer3.10.expand1x1.weight |   131072   |
# |  layer3.10.expand1x1.bias  |    512     |
# | layer3.10.expand3x3.weight |  1179648   |
# |  layer3.10.expand3x3.bias  |    512     |
# |  layer3.11.squeeze.weight  |   262144   |
# |   layer3.11.squeeze.bias   |    256     |
# | layer3.11.expand1x1.weight |   131072   |
# |  layer3.11.expand1x1.bias  |    512     |
# | layer3.11.expand3x3.weight |  1179648   |
# |  layer3.11.expand3x3.bias  |    512     |
# |  layer3.12.squeeze.weight  |   262144   |
# |   layer3.12.squeeze.bias   |    256     |
# | layer3.12.expand1x1.weight |   131072   |
# |  layer3.12.expand1x1.bias  |    512     |
# | layer3.12.expand3x3.weight |  1179648   |
# |  layer3.12.expand3x3.bias  |    512     |
# |  layer3.13.squeeze.weight  |   262144   |
# |   layer3.13.squeeze.bias   |    256     |
# | layer3.13.expand1x1.weight |   131072   |
# |  layer3.13.expand1x1.bias  |    512     |
# | layer3.13.expand3x3.weight |  1179648   |
# |  layer3.13.expand3x3.bias  |    512     |
# |  layer3.14.squeeze.weight  |   262144   |
# |   layer3.14.squeeze.bias   |    256     |
# | layer3.14.expand1x1.weight |   131072   |
# |  layer3.14.expand1x1.bias  |    512     |
# | layer3.14.expand3x3.weight |  1179648   |
# |  layer3.14.expand3x3.bias  |    512     |
# |  layer3.15.squeeze.weight  |   262144   |
# |   layer3.15.squeeze.bias   |    256     |
# | layer3.15.expand1x1.weight |   131072   |
# |  layer3.15.expand1x1.bias  |    512     |
# | layer3.15.expand3x3.weight |  1179648   |
# |  layer3.15.expand3x3.bias  |    512     |
# |  layer3.16.squeeze.weight  |   262144   |
# |   layer3.16.squeeze.bias   |    256     |
# | layer3.16.expand1x1.weight |   131072   |
# |  layer3.16.expand1x1.bias  |    512     |
# | layer3.16.expand3x3.weight |  1179648   |
# |  layer3.16.expand3x3.bias  |    512     |
# |  layer3.17.squeeze.weight  |   262144   |
# |   layer3.17.squeeze.bias   |    256     |
# | layer3.17.expand1x1.weight |   131072   |
# |  layer3.17.expand1x1.bias  |    512     |
# | layer3.17.expand3x3.weight |  1179648   |
# |  layer3.17.expand3x3.bias  |    512     |
# |  layer3.18.squeeze.weight  |   262144   |
# |   layer3.18.squeeze.bias   |    256     |
# | layer3.18.expand1x1.weight |   131072   |
# |  layer3.18.expand1x1.bias  |    512     |
# | layer3.18.expand3x3.weight |  1179648   |
# |  layer3.18.expand3x3.bias  |    512     |
# |  layer3.19.squeeze.weight  |   262144   |
# |   layer3.19.squeeze.bias   |    256     |
# | layer3.19.expand1x1.weight |   131072   |
# |  layer3.19.expand1x1.bias  |    512     |
# | layer3.19.expand3x3.weight |  1179648   |
# |  layer3.19.expand3x3.bias  |    512     |
# |  layer3.20.squeeze.weight  |   262144   |
# |   layer3.20.squeeze.bias   |    256     |
# | layer3.20.expand1x1.weight |   131072   |
# |  layer3.20.expand1x1.bias  |    512     |
# | layer3.20.expand3x3.weight |  1179648   |
# |  layer3.20.expand3x3.bias  |    512     |
# |  layer3.21.squeeze.weight  |   262144   |
# |   layer3.21.squeeze.bias   |    256     |
# | layer3.21.expand1x1.weight |   131072   |
# |  layer3.21.expand1x1.bias  |    512     |
# | layer3.21.expand3x3.weight |  1179648   |
# |  layer3.21.expand3x3.bias  |    512     |
# |  layer3.22.squeeze.weight  |   262144   |
# |   layer3.22.squeeze.bias   |    256     |
# | layer3.22.expand1x1.weight |   131072   |
# |  layer3.22.expand1x1.bias  |    512     |
# | layer3.22.expand3x3.weight |  1179648   |
# |  layer3.22.expand3x3.bias  |    512     |
# |  layer4.0.squeeze.weight   |   524288   |
# |   layer4.0.squeeze.bias    |    512     |
# | layer4.0.expand1x1.weight  |   524288   |
# |  layer4.0.expand1x1.bias   |    1024    |
# | layer4.0.expand3x3.weight  |  4718592   |
# |  layer4.0.expand3x3.bias   |    1024    |
# |  layer4.1.squeeze.weight   |  1048576   |
# |   layer4.1.squeeze.bias    |    512     |
# | layer4.1.expand1x1.weight  |   524288   |
# |  layer4.1.expand1x1.bias   |    1024    |
# | layer4.1.expand3x3.weight  |  4718592   |
# |  layer4.1.expand3x3.bias   |    1024    |
# |  layer4.2.squeeze.weight   |  1048576   |
# |   layer4.2.squeeze.bias    |    512     |
# | layer4.2.expand1x1.weight  |   524288   |
# |  layer4.2.expand1x1.bias   |    1024    |
# | layer4.2.expand3x3.weight  |  4718592   |
# |  layer4.2.expand3x3.bias   |    1024    |
# |         fc.weight          |   20480    |
# |          fc.bias           |     10     |
# +----------------------------+------------+
# Total Trainable Params: 56280586
# Total Params:  56280586

# %%
pip install -U fvcore
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 KB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from fvcore) (1.21.6)
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from fvcore) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from fvcore) (4.64.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.8/dist-packages (from fvcore) (2.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from fvcore) (7.1.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from fvcore) (0.8.10)
# Collecting iopath>=0.1.7
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 KB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.8/dist-packages (from iopath>=0.1.7->fvcore) (4.4.0)
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61431 sha256=1339241ae5e4335dd5405485900c63e7b239a40edf5b6c8ba3f57fe6eb9a2aef
#   Stored in directory: /root/.cache/pip/wheels/b8/79/07/c0e9367f5b5ea325e246bd73651e8af175fabbef943043b1cc
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=079e4bc6d6cfb42d31b2b898493afda7a72d8b22e93df616c6dcef6db730bae5
#   Stored in directory: /root/.cache/pip/wheels/89/3e/24/0f349c0b2eeb6965903035f3b00dbb5c9bea437b4a2f18d82c
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-2.6.0 yacs-0.1.8

# %%
from fvcore.nn import FlopCountAnalysis
from fvcore.nn import flop_count_table

input =  torch.rand(1, 3, 32, 32)

flops = FlopCountAnalysis(model, input)
print(flop_count_table(flops))
print("Total number of FLOPS: ", flops.total())
# Out:
# | module                 | #parameters or shape   | #flops     |
# |:-----------------------|:-----------------------|:-----------|
# | model                  | 56.281M                | 3.362G     |
# |  conv1                 |  1.728K                |  1.769M    |
# |   conv1.weight         |   (64, 3, 3, 3)        |            |
# |  bn1                   |  0.128K                |  0.131M    |
# |   bn1.weight           |   (64,)                |            |
# |   bn1.bias             |   (64,)                |            |
# |  layer1                |  0.284M                |  0.289G    |
# |   layer1.0             |   86.336K              |   88.08M   |
# |    layer1.0.squeeze    |    4.16K               |    4.194M  |
# |    layer1.0.expand1x1  |    8.32K               |    8.389M  |
# |    layer1.0.expand3x3  |    73.856K             |    75.497M |
# |   layer1.1             |   98.624K              |   0.101G   |
# |    layer1.1.squeeze    |    16.448K             |    16.777M |
# |    layer1.1.expand1x1  |    8.32K               |    8.389M  |
# |    layer1.1.expand3x3  |    73.856K             |    75.497M |
# |   layer1.2             |   98.624K              |   0.101G   |
# |    layer1.2.squeeze    |    16.448K             |    16.777M |
# |    layer1.2.expand1x1  |    8.32K               |    8.389M  |
# |    layer1.2.expand3x3  |    73.856K             |    75.497M |
# |  layer2                |  1.543M                |  0.419G    |
# |   layer2.0             |   0.361M               |   0.117G   |
# |    layer2.0.squeeze    |    32.896K             |    33.554M |
# |    layer2.0.expand1x1  |    33.024K             |    8.389M  |
# |    layer2.0.expand3x3  |    0.295M              |    75.497M |
# |   layer2.1             |   0.394M               |   0.101G   |
# |    layer2.1.squeeze    |    65.664K             |    16.777M |
# |    layer2.1.expand1x1  |    33.024K             |    8.389M  |
# |    layer2.1.expand3x3  |    0.295M              |    75.497M |
# |   layer2.2             |   0.394M               |   0.101G   |
# |    layer2.2.squeeze    |    65.664K             |    16.777M |
# |    layer2.2.expand1x1  |    33.024K             |    8.389M  |
# |    layer2.2.expand3x3  |    0.295M              |    75.497M |
# |   layer2.3             |   0.394M               |   0.101G   |
# |    layer2.3.squeeze    |    65.664K             |    16.777M |
# |    layer2.3.expand1x1  |    33.024K             |    8.389M  |
# |    layer2.3.expand3x3  |    0.295M              |    75.497M |
# |  layer3                |  36.074M               |  2.332G    |
# |   layer3.0             |   1.443M               |   0.117G   |
# |    layer3.0.squeeze    |    0.131M              |    33.554M |
# |    layer3.0.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.0.expand3x3  |    1.18M               |    75.497M |
# |   layer3.1             |   1.574M               |   0.101G   |
# |    layer3.1.squeeze    |    0.262M              |    16.777M |
# |    layer3.1.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.1.expand3x3  |    1.18M               |    75.497M |
# |   layer3.2             |   1.574M               |   0.101G   |
# |    layer3.2.squeeze    |    0.262M              |    16.777M |
# |    layer3.2.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.2.expand3x3  |    1.18M               |    75.497M |
# |   layer3.3             |   1.574M               |   0.101G   |
# |    layer3.3.squeeze    |    0.262M              |    16.777M |
# |    layer3.3.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.3.expand3x3  |    1.18M               |    75.497M |
# |   layer3.4             |   1.574M               |   0.101G   |
# |    layer3.4.squeeze    |    0.262M              |    16.777M |
# |    layer3.4.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.4.expand3x3  |    1.18M               |    75.497M |
# |   layer3.5             |   1.574M               |   0.101G   |
# |    layer3.5.squeeze    |    0.262M              |    16.777M |
# |    layer3.5.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.5.expand3x3  |    1.18M               |    75.497M |
# |   layer3.6             |   1.574M               |   0.101G   |
# |    layer3.6.squeeze    |    0.262M              |    16.777M |
# |    layer3.6.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.6.expand3x3  |    1.18M               |    75.497M |
# |   layer3.7             |   1.574M               |   0.101G   |
# |    layer3.7.squeeze    |    0.262M              |    16.777M |
# |    layer3.7.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.7.expand3x3  |    1.18M               |    75.497M |
# |   layer3.8             |   1.574M               |   0.101G   |
# |    layer3.8.squeeze    |    0.262M              |    16.777M |
# |    layer3.8.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.8.expand3x3  |    1.18M               |    75.497M |
# |   layer3.9             |   1.574M               |   0.101G   |
# |    layer3.9.squeeze    |    0.262M              |    16.777M |
# |    layer3.9.expand1x1  |    0.132M              |    8.389M  |
# |    layer3.9.expand3x3  |    1.18M               |    75.497M |
# |   layer3.10            |   1.574M               |   0.101G   |
# |    layer3.10.squeeze   |    0.262M              |    16.777M |
# |    layer3.10.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.10.expand3x3 |    1.18M               |    75.497M |
# |   layer3.11            |   1.574M               |   0.101G   |
# |    layer3.11.squeeze   |    0.262M              |    16.777M |
# |    layer3.11.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.11.expand3x3 |    1.18M               |    75.497M |
# |   layer3.12            |   1.574M               |   0.101G   |
# |    layer3.12.squeeze   |    0.262M              |    16.777M |
# |    layer3.12.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.12.expand3x3 |    1.18M               |    75.497M |
# |   layer3.13            |   1.574M               |   0.101G   |
# |    layer3.13.squeeze   |    0.262M              |    16.777M |
# |    layer3.13.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.13.expand3x3 |    1.18M               |    75.497M |
# |   layer3.14            |   1.574M               |   0.101G   |
# |    layer3.14.squeeze   |    0.262M              |    16.777M |
# |    layer3.14.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.14.expand3x3 |    1.18M               |    75.497M |
# |   layer3.15            |   1.574M               |   0.101G   |
# |    layer3.15.squeeze   |    0.262M              |    16.777M |
# |    layer3.15.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.15.expand3x3 |    1.18M               |    75.497M |
# |   layer3.16            |   1.574M               |   0.101G   |
# |    layer3.16.squeeze   |    0.262M              |    16.777M |
# |    layer3.16.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.16.expand3x3 |    1.18M               |    75.497M |
# |   layer3.17            |   1.574M               |   0.101G   |
# |    layer3.17.squeeze   |    0.262M              |    16.777M |
# |    layer3.17.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.17.expand3x3 |    1.18M               |    75.497M |
# |   layer3.18            |   1.574M               |   0.101G   |
# |    layer3.18.squeeze   |    0.262M              |    16.777M |
# |    layer3.18.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.18.expand3x3 |    1.18M               |    75.497M |
# |   layer3.19            |   1.574M               |   0.101G   |
# |    layer3.19.squeeze   |    0.262M              |    16.777M |
# |    layer3.19.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.19.expand3x3 |    1.18M               |    75.497M |
# |   layer3.20            |   1.574M               |   0.101G   |
# |    layer3.20.squeeze   |    0.262M              |    16.777M |
# |    layer3.20.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.20.expand3x3 |    1.18M               |    75.497M |
# |   layer3.21            |   1.574M               |   0.101G   |
# |    layer3.21.squeeze   |    0.262M              |    16.777M |
# |    layer3.21.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.21.expand3x3 |    1.18M               |    75.497M |
# |   layer3.22            |   1.574M               |   0.101G   |
# |    layer3.22.squeeze   |    0.262M              |    16.777M |
# |    layer3.22.expand1x1 |    0.132M              |    8.389M  |
# |    layer3.22.expand3x3 |    1.18M               |    75.497M |
# |  layer4                |  18.358M               |  0.319G    |
# |   layer4.0             |   5.77M                |   0.117G   |
# |    layer4.0.squeeze    |    0.525M              |    33.554M |
# |    layer4.0.expand1x1  |    0.525M              |    8.389M  |
# |    layer4.0.expand3x3  |    4.72M               |    75.497M |
# |   layer4.1             |   6.294M               |   0.101G   |
# |    layer4.1.squeeze    |    1.049M              |    16.777M |
# |    layer4.1.expand1x1  |    0.525M              |    8.389M  |
# |    layer4.1.expand3x3  |    4.72M               |    75.497M |
# |   layer4.2             |   6.294M               |   0.101G   |
# |    layer4.2.squeeze    |    1.049M              |    16.777M |
# |    layer4.2.expand1x1  |    0.525M              |    8.389M  |
# |    layer4.2.expand3x3  |    4.72M               |    75.497M |
# |  fc                    |  20.49K                |  20.48K    |
# |   fc.weight            |   (10, 2048)           |            |
# |   fc.bias              |   (10,)                |            |
# |  avgpool               |                        |  32.768K   |
# Total number of FLOPS:  3361591296

# %% [markdown]
# # Conclusion
# The numbers of parameters and FLOPs are too big for further research.
