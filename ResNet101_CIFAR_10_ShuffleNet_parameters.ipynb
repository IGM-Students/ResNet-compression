# %% [markdown]
# # Load model from google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')


#set your path in google drive where model is kept
PATH = '/content/gdrive/MyDrive/ShuffleNet/resnet101_shuffleNet.132.h5';
# Out:
# Mounted at /content/gdrive

# %%
import torch
import torchvision
import torch.nn as nn

# %% [markdown]
# ## Load model ResNet101 with ShuffleNet blocks Cifar10

# %%
def conv1x1(in_channels,
            out_channels,
            stride=1,
            groups=1,
            bias=False):
    """
    Convolution 1x1 layer.
    Parameters:
    ----------
    in_channels : int
        Number of input channels.
    out_channels : int
        Number of output channels.
    stride : int or tuple/list of 2 int, default 1
        Strides of the convolution.
    groups : int, default 1
        Number of groups.
    bias : bool, default False
        Whether the layer uses a bias vector.
    """
    return nn.Conv2d(
        in_channels=in_channels,
        out_channels=out_channels,
        kernel_size=1,
        stride=stride,
        groups=groups,
        bias=bias)


def conv3x3(in_channels,
            out_channels,
            stride=1,
            padding=1,
            dilation=1,
            groups=1,
            bias=False):
    """
    Convolution 3x3 layer.
    Parameters:
    ----------
    in_channels : int
        Number of input channels.
    out_channels : int
        Number of output channels.
    stride : int or tuple/list of 2 int, default 1
        Strides of the convolution.
    padding : int or tuple/list of 2 int, default 1
        Padding value for convolution layer.
    groups : int, default 1
        Number of groups.
    bias : bool, default False
        Whether the layer uses a bias vector.
    """
    return nn.Conv2d(
        in_channels=in_channels,
        out_channels=out_channels,
        kernel_size=3,
        stride=stride,
        padding=padding,
        dilation=dilation,
        groups=groups,
        bias=bias)
    
def conv3x3(in_channels,
            out_channels,
            stride=1,
            padding=1,
            dilation=1,
            groups=1,
            bias=False):
    """
    Convolution 3x3 layer.
    Parameters:
    ----------
    in_channels : int
        Number of input channels.
    out_channels : int
        Number of output channels.
    stride : int or tuple/list of 2 int, default 1
        Strides of the convolution.
    padding : int or tuple/list of 2 int, default 1
        Padding value for convolution layer.
    groups : int, default 1
        Number of groups.
    bias : bool, default False
        Whether the layer uses a bias vector.
    """
    return nn.Conv2d(
        in_channels=in_channels,
        out_channels=out_channels,
        kernel_size=3,
        stride=stride,
        padding=padding,
        dilation=dilation,
        groups=groups,
        bias=bias)


def depthwise_conv3x3(channels,
                      stride):
    """
    Depthwise convolution 3x3 layer.
    Parameters:
    ----------
    channels : int
        Number of input/output channels.
    strides : int or tuple/list of 2 int
        Strides of the convolution.
    """
    return nn.Conv2d(
        in_channels=channels,
        out_channels=channels,
        kernel_size=3,
        stride=stride,
        padding=1,
        groups=channels,
        bias=False)

def channel_shuffle(x,
                    groups):
    """
    Channel shuffle operation from 'ShuffleNet: An Extremely Efficient Convolutional Neural Network for Mobile Devices,'
    https://arxiv.org/abs/1707.01083.
    Parameters:
    ----------
    x : Tensor
        Input tensor.
    groups : int
        Number of groups.
    Returns
    -------
    Tensor
        Resulted tensor.
    """
    batch, channels, height, width = x.size()
    # assert (channels % groups == 0)
    channels_per_group = channels // groups
    x = x.view(batch, groups, channels_per_group, height, width)
    x = torch.transpose(x, 1, 2).contiguous()
    x = x.view(batch, channels, height, width)
    return x

class ChannelShuffle(nn.Module):
    """
    Channel shuffle layer. This is a wrapper over the same operation. It is designed to save the number of groups.
    Parameters:
    ----------
    channels : int
        Number of channels.
    groups : int
        Number of groups.
    """
    def __init__(self,
                 channels,
                 groups):
        super(ChannelShuffle, self).__init__()
        # assert (channels % groups == 0)
        if channels % groups != 0:
            raise ValueError('channels must be divisible by groups')
        self.groups = groups

    def forward(self, x):
        return channel_shuffle(x, self.groups)

# %%
class ShuffleUnit(nn.Module):
    """
    ShuffleNet unit.
    Parameters:
    ----------
    in_channels : int
        Number of input channels.
    out_channels : int
        Number of output channels.
    groups : int
        Number of groups in convolution layers.
    downsample : bool
        Whether do downsample.
    ignore_group : bool
        Whether ignore group value in the first convolution layer.
    """
    def __init__(self,
                 in_channels,
                 out_channels,
                 groups,
                 downsample,
                 ignore_group, expand):
        super(ShuffleUnit, self).__init__()
        self.downsample = downsample
        self.expand = expand
        mid_channels = out_channels // 4

        if downsample:
            out_channels -= in_channels

        self.compress_conv1 = conv1x1(
            in_channels=in_channels,
            out_channels=mid_channels,
            groups=(1 if ignore_group else groups))
        self.compress_bn1 = nn.BatchNorm2d(num_features=mid_channels)
        self.c_shuffle = ChannelShuffle(
            channels=mid_channels,
            groups=groups)
        self.dw_conv2 = depthwise_conv3x3(
            channels=mid_channels,
            stride=(2 if self.downsample else 1))
        self.dw_bn2 = nn.BatchNorm2d(num_features=mid_channels)
        self.expand_conv3 = conv1x1(
            in_channels=mid_channels,
            out_channels=out_channels,
            groups=groups)
        if self.expand:
          self.expandConv = conv1x1(in_channels,
            out_channels= in_channels* 4,
            groups = groups)
        self.expand_bn3 = nn.BatchNorm2d(num_features=out_channels)
        if downsample:
            self.avgpool = nn.AvgPool2d(kernel_size=3, stride=2, padding=1)
        self.activ = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x
        if self.expand:
          identity = self.expandConv(identity)
        x = self.compress_conv1(x)
        x = self.compress_bn1(x)
        x = self.activ(x)
        x = self.c_shuffle(x)
        x = self.dw_conv2(x)
        x = self.expand_conv3(x)
        x = self.expand_bn3(x)
        if self.downsample:
            identity = self.avgpool(identity)
            x = torch.cat((x, identity), dim=1)
        else:
            x = x + identity
        x = self.activ(x)
        return x

# %%
from torchvision.models import resnet101

model = resnet101(pretrained=False, num_classes=10)

model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
model.maxpool = nn.Identity()

model.layer1[0] = ShuffleUnit(64, 256, 8, False, True, True)
model.layer1[1] = ShuffleUnit(256, 256, 8, False, True, False)
model.layer1[2] = ShuffleUnit(256, 256, 8, False, True, False)
model.layer2[0] = ShuffleUnit(256, 512, 8, True, True, False)
model.layer2[1] = ShuffleUnit(512, 512, 8, False, True, False)
model.layer2[2] = ShuffleUnit(512, 512, 8, False, True, False)
model.layer2[3] = ShuffleUnit(512, 512, 8, False, True, False)
model.layer3[0] = ShuffleUnit(512, 1024, 8, True, True, False)
model.layer3[1] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[2] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[3] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[4] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[5] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[6] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[7] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[8] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[9] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[10] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[11] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[12] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[13] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[14] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[15] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[16] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[17] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[18] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[19] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[20] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[21] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer3[22] = ShuffleUnit(1024, 1024, 8, False, True, False)
model.layer4[0] = ShuffleUnit(1024, 2048, 8, True, True, False)
model.layer4[1] = ShuffleUnit(2048, 2048, 8, False, True, False)
model.layer4[2] = ShuffleUnit(2048, 2048, 8, False, True, False)

model.load_state_dict(torch.load(PATH))
model.eval()
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): Identity()
#   (layer1): Sequential(
#     (0): ShuffleUnit(
#       (compress_conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (dw_bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expandConv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (1): ShuffleUnit(
#       (compress_conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (dw_bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (2): ShuffleUnit(
#       (compress_conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (dw_bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): ShuffleUnit(
#       (compress_conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#       (dw_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (avgpool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       (activ): ReLU(inplace=True)
#     )
#     (1): ShuffleUnit(
#       (compress_conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (dw_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (2): ShuffleUnit(
#       (compress_conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (dw_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (3): ShuffleUnit(
#       (compress_conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (dw_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): ShuffleUnit(
#       (compress_conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (avgpool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       (activ): ReLU(inplace=True)
#     )
#     (1): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (2): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (3): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (4): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (5): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (6): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (7): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (8): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (9): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (10): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (11): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (12): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (13): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (14): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (15): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (16): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (17): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (18): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (19): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (20): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (21): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (22): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (dw_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): ShuffleUnit(
#       (compress_conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512, bias=False)
#       (dw_bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (avgpool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       (activ): ReLU(inplace=True)
#     )
#     (1): ShuffleUnit(
#       (compress_conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (dw_bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#     (2): ShuffleUnit(
#       (compress_conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (compress_bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (c_shuffle): ChannelShuffle()
#       (dw_conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (dw_bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (expand_conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), groups=8, bias=False)
#       (expand_bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activ): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

count_parameters(model)

pytorch_total_params = sum(p.numel() for p in model.parameters())
print("Total Params: ", pytorch_total_params)
# Out:
# +---------------------------------+------------+
# |             Modules             | Parameters |
# +---------------------------------+------------+
# |           conv1.weight          |    1728    |
# |            bn1.weight           |     64     |
# |             bn1.bias            |     64     |
# |  layer1.0.compress_conv1.weight |    4096    |
# |   layer1.0.compress_bn1.weight  |     64     |
# |    layer1.0.compress_bn1.bias   |     64     |
# |     layer1.0.dw_conv2.weight    |    576     |
# |      layer1.0.dw_bn2.weight     |     64     |
# |       layer1.0.dw_bn2.bias      |     64     |
# |   layer1.0.expand_conv3.weight  |    2048    |
# |    layer1.0.expandConv.weight   |    2048    |
# |    layer1.0.expand_bn3.weight   |    256     |
# |     layer1.0.expand_bn3.bias    |    256     |
# |  layer1.1.compress_conv1.weight |   16384    |
# |   layer1.1.compress_bn1.weight  |     64     |
# |    layer1.1.compress_bn1.bias   |     64     |
# |     layer1.1.dw_conv2.weight    |    576     |
# |      layer1.1.dw_bn2.weight     |     64     |
# |       layer1.1.dw_bn2.bias      |     64     |
# |   layer1.1.expand_conv3.weight  |    2048    |
# |    layer1.1.expand_bn3.weight   |    256     |
# |     layer1.1.expand_bn3.bias    |    256     |
# |  layer1.2.compress_conv1.weight |   16384    |
# |   layer1.2.compress_bn1.weight  |     64     |
# |    layer1.2.compress_bn1.bias   |     64     |
# |     layer1.2.dw_conv2.weight    |    576     |
# |      layer1.2.dw_bn2.weight     |     64     |
# |       layer1.2.dw_bn2.bias      |     64     |
# |   layer1.2.expand_conv3.weight  |    2048    |
# |    layer1.2.expand_bn3.weight   |    256     |
# |     layer1.2.expand_bn3.bias    |    256     |
# |  layer2.0.compress_conv1.weight |   32768    |
# |   layer2.0.compress_bn1.weight  |    128     |
# |    layer2.0.compress_bn1.bias   |    128     |
# |     layer2.0.dw_conv2.weight    |    1152    |
# |      layer2.0.dw_bn2.weight     |    128     |
# |       layer2.0.dw_bn2.bias      |    128     |
# |   layer2.0.expand_conv3.weight  |    4096    |
# |    layer2.0.expand_bn3.weight   |    256     |
# |     layer2.0.expand_bn3.bias    |    256     |
# |  layer2.1.compress_conv1.weight |   65536    |
# |   layer2.1.compress_bn1.weight  |    128     |
# |    layer2.1.compress_bn1.bias   |    128     |
# |     layer2.1.dw_conv2.weight    |    1152    |
# |      layer2.1.dw_bn2.weight     |    128     |
# |       layer2.1.dw_bn2.bias      |    128     |
# |   layer2.1.expand_conv3.weight  |    8192    |
# |    layer2.1.expand_bn3.weight   |    512     |
# |     layer2.1.expand_bn3.bias    |    512     |
# |  layer2.2.compress_conv1.weight |   65536    |
# |   layer2.2.compress_bn1.weight  |    128     |
# |    layer2.2.compress_bn1.bias   |    128     |
# |     layer2.2.dw_conv2.weight    |    1152    |
# |      layer2.2.dw_bn2.weight     |    128     |
# |       layer2.2.dw_bn2.bias      |    128     |
# |   layer2.2.expand_conv3.weight  |    8192    |
# |    layer2.2.expand_bn3.weight   |    512     |
# |     layer2.2.expand_bn3.bias    |    512     |
# |  layer2.3.compress_conv1.weight |   65536    |
# |   layer2.3.compress_bn1.weight  |    128     |
# |    layer2.3.compress_bn1.bias   |    128     |
# |     layer2.3.dw_conv2.weight    |    1152    |
# |      layer2.3.dw_bn2.weight     |    128     |
# |       layer2.3.dw_bn2.bias      |    128     |
# |   layer2.3.expand_conv3.weight  |    8192    |
# |    layer2.3.expand_bn3.weight   |    512     |
# |     layer2.3.expand_bn3.bias    |    512     |
# |  layer3.0.compress_conv1.weight |   131072   |
# |   layer3.0.compress_bn1.weight  |    256     |
# |    layer3.0.compress_bn1.bias   |    256     |
# |     layer3.0.dw_conv2.weight    |    2304    |
# |      layer3.0.dw_bn2.weight     |    256     |
# |       layer3.0.dw_bn2.bias      |    256     |
# |   layer3.0.expand_conv3.weight  |   16384    |
# |    layer3.0.expand_bn3.weight   |    512     |
# |     layer3.0.expand_bn3.bias    |    512     |
# |  layer3.1.compress_conv1.weight |   262144   |
# |   layer3.1.compress_bn1.weight  |    256     |
# |    layer3.1.compress_bn1.bias   |    256     |
# |     layer3.1.dw_conv2.weight    |    2304    |
# |      layer3.1.dw_bn2.weight     |    256     |
# |       layer3.1.dw_bn2.bias      |    256     |
# |   layer3.1.expand_conv3.weight  |   32768    |
# |    layer3.1.expand_bn3.weight   |    1024    |
# |     layer3.1.expand_bn3.bias    |    1024    |
# |  layer3.2.compress_conv1.weight |   262144   |
# |   layer3.2.compress_bn1.weight  |    256     |
# |    layer3.2.compress_bn1.bias   |    256     |
# |     layer3.2.dw_conv2.weight    |    2304    |
# |      layer3.2.dw_bn2.weight     |    256     |
# |       layer3.2.dw_bn2.bias      |    256     |
# |   layer3.2.expand_conv3.weight  |   32768    |
# |    layer3.2.expand_bn3.weight   |    1024    |
# |     layer3.2.expand_bn3.bias    |    1024    |
# |  layer3.3.compress_conv1.weight |   262144   |
# |   layer3.3.compress_bn1.weight  |    256     |
# |    layer3.3.compress_bn1.bias   |    256     |
# |     layer3.3.dw_conv2.weight    |    2304    |
# |      layer3.3.dw_bn2.weight     |    256     |
# |       layer3.3.dw_bn2.bias      |    256     |
# |   layer3.3.expand_conv3.weight  |   32768    |
# |    layer3.3.expand_bn3.weight   |    1024    |
# |     layer3.3.expand_bn3.bias    |    1024    |
# |  layer3.4.compress_conv1.weight |   262144   |
# |   layer3.4.compress_bn1.weight  |    256     |
# |    layer3.4.compress_bn1.bias   |    256     |
# |     layer3.4.dw_conv2.weight    |    2304    |
# |      layer3.4.dw_bn2.weight     |    256     |
# |       layer3.4.dw_bn2.bias      |    256     |
# |   layer3.4.expand_conv3.weight  |   32768    |
# |    layer3.4.expand_bn3.weight   |    1024    |
# |     layer3.4.expand_bn3.bias    |    1024    |
# |  layer3.5.compress_conv1.weight |   262144   |
# |   layer3.5.compress_bn1.weight  |    256     |
# |    layer3.5.compress_bn1.bias   |    256     |
# |     layer3.5.dw_conv2.weight    |    2304    |
# |      layer3.5.dw_bn2.weight     |    256     |
# |       layer3.5.dw_bn2.bias      |    256     |
# |   layer3.5.expand_conv3.weight  |   32768    |
# |    layer3.5.expand_bn3.weight   |    1024    |
# |     layer3.5.expand_bn3.bias    |    1024    |
# |  layer3.6.compress_conv1.weight |   262144   |
# |   layer3.6.compress_bn1.weight  |    256     |
# |    layer3.6.compress_bn1.bias   |    256     |
# |     layer3.6.dw_conv2.weight    |    2304    |
# |      layer3.6.dw_bn2.weight     |    256     |
# |       layer3.6.dw_bn2.bias      |    256     |
# |   layer3.6.expand_conv3.weight  |   32768    |
# |    layer3.6.expand_bn3.weight   |    1024    |
# |     layer3.6.expand_bn3.bias    |    1024    |
# |  layer3.7.compress_conv1.weight |   262144   |
# |   layer3.7.compress_bn1.weight  |    256     |
# |    layer3.7.compress_bn1.bias   |    256     |
# |     layer3.7.dw_conv2.weight    |    2304    |
# |      layer3.7.dw_bn2.weight     |    256     |
# |       layer3.7.dw_bn2.bias      |    256     |
# |   layer3.7.expand_conv3.weight  |   32768    |
# |    layer3.7.expand_bn3.weight   |    1024    |
# |     layer3.7.expand_bn3.bias    |    1024    |
# |  layer3.8.compress_conv1.weight |   262144   |
# |   layer3.8.compress_bn1.weight  |    256     |
# |    layer3.8.compress_bn1.bias   |    256     |
# |     layer3.8.dw_conv2.weight    |    2304    |
# |      layer3.8.dw_bn2.weight     |    256     |
# |       layer3.8.dw_bn2.bias      |    256     |
# |   layer3.8.expand_conv3.weight  |   32768    |
# |    layer3.8.expand_bn3.weight   |    1024    |
# |     layer3.8.expand_bn3.bias    |    1024    |
# |  layer3.9.compress_conv1.weight |   262144   |
# |   layer3.9.compress_bn1.weight  |    256     |
# |    layer3.9.compress_bn1.bias   |    256     |
# |     layer3.9.dw_conv2.weight    |    2304    |
# |      layer3.9.dw_bn2.weight     |    256     |
# |       layer3.9.dw_bn2.bias      |    256     |
# |   layer3.9.expand_conv3.weight  |   32768    |
# |    layer3.9.expand_bn3.weight   |    1024    |
# |     layer3.9.expand_bn3.bias    |    1024    |
# | layer3.10.compress_conv1.weight |   262144   |
# |  layer3.10.compress_bn1.weight  |    256     |
# |   layer3.10.compress_bn1.bias   |    256     |
# |    layer3.10.dw_conv2.weight    |    2304    |
# |     layer3.10.dw_bn2.weight     |    256     |
# |      layer3.10.dw_bn2.bias      |    256     |
# |  layer3.10.expand_conv3.weight  |   32768    |
# |   layer3.10.expand_bn3.weight   |    1024    |
# |    layer3.10.expand_bn3.bias    |    1024    |
# | layer3.11.compress_conv1.weight |   262144   |
# |  layer3.11.compress_bn1.weight  |    256     |
# |   layer3.11.compress_bn1.bias   |    256     |
# |    layer3.11.dw_conv2.weight    |    2304    |
# |     layer3.11.dw_bn2.weight     |    256     |
# |      layer3.11.dw_bn2.bias      |    256     |
# |  layer3.11.expand_conv3.weight  |   32768    |
# |   layer3.11.expand_bn3.weight   |    1024    |
# |    layer3.11.expand_bn3.bias    |    1024    |
# | layer3.12.compress_conv1.weight |   262144   |
# |  layer3.12.compress_bn1.weight  |    256     |
# |   layer3.12.compress_bn1.bias   |    256     |
# |    layer3.12.dw_conv2.weight    |    2304    |
# |     layer3.12.dw_bn2.weight     |    256     |
# |      layer3.12.dw_bn2.bias      |    256     |
# |  layer3.12.expand_conv3.weight  |   32768    |
# |   layer3.12.expand_bn3.weight   |    1024    |
# |    layer3.12.expand_bn3.bias    |    1024    |
# | layer3.13.compress_conv1.weight |   262144   |
# |  layer3.13.compress_bn1.weight  |    256     |
# |   layer3.13.compress_bn1.bias   |    256     |
# |    layer3.13.dw_conv2.weight    |    2304    |
# |     layer3.13.dw_bn2.weight     |    256     |
# |      layer3.13.dw_bn2.bias      |    256     |
# |  layer3.13.expand_conv3.weight  |   32768    |
# |   layer3.13.expand_bn3.weight   |    1024    |
# |    layer3.13.expand_bn3.bias    |    1024    |
# | layer3.14.compress_conv1.weight |   262144   |
# |  layer3.14.compress_bn1.weight  |    256     |
# |   layer3.14.compress_bn1.bias   |    256     |
# |    layer3.14.dw_conv2.weight    |    2304    |
# |     layer3.14.dw_bn2.weight     |    256     |
# |      layer3.14.dw_bn2.bias      |    256     |
# |  layer3.14.expand_conv3.weight  |   32768    |
# |   layer3.14.expand_bn3.weight   |    1024    |
# |    layer3.14.expand_bn3.bias    |    1024    |
# | layer3.15.compress_conv1.weight |   262144   |
# |  layer3.15.compress_bn1.weight  |    256     |
# |   layer3.15.compress_bn1.bias   |    256     |
# |    layer3.15.dw_conv2.weight    |    2304    |
# |     layer3.15.dw_bn2.weight     |    256     |
# |      layer3.15.dw_bn2.bias      |    256     |
# |  layer3.15.expand_conv3.weight  |   32768    |
# |   layer3.15.expand_bn3.weight   |    1024    |
# |    layer3.15.expand_bn3.bias    |    1024    |
# | layer3.16.compress_conv1.weight |   262144   |
# |  layer3.16.compress_bn1.weight  |    256     |
# |   layer3.16.compress_bn1.bias   |    256     |
# |    layer3.16.dw_conv2.weight    |    2304    |
# |     layer3.16.dw_bn2.weight     |    256     |
# |      layer3.16.dw_bn2.bias      |    256     |
# |  layer3.16.expand_conv3.weight  |   32768    |
# |   layer3.16.expand_bn3.weight   |    1024    |
# |    layer3.16.expand_bn3.bias    |    1024    |
# | layer3.17.compress_conv1.weight |   262144   |
# |  layer3.17.compress_bn1.weight  |    256     |
# |   layer3.17.compress_bn1.bias   |    256     |
# |    layer3.17.dw_conv2.weight    |    2304    |
# |     layer3.17.dw_bn2.weight     |    256     |
# |      layer3.17.dw_bn2.bias      |    256     |
# |  layer3.17.expand_conv3.weight  |   32768    |
# |   layer3.17.expand_bn3.weight   |    1024    |
# |    layer3.17.expand_bn3.bias    |    1024    |
# | layer3.18.compress_conv1.weight |   262144   |
# |  layer3.18.compress_bn1.weight  |    256     |
# |   layer3.18.compress_bn1.bias   |    256     |
# |    layer3.18.dw_conv2.weight    |    2304    |
# |     layer3.18.dw_bn2.weight     |    256     |
# |      layer3.18.dw_bn2.bias      |    256     |
# |  layer3.18.expand_conv3.weight  |   32768    |
# |   layer3.18.expand_bn3.weight   |    1024    |
# |    layer3.18.expand_bn3.bias    |    1024    |
# | layer3.19.compress_conv1.weight |   262144   |
# |  layer3.19.compress_bn1.weight  |    256     |
# |   layer3.19.compress_bn1.bias   |    256     |
# |    layer3.19.dw_conv2.weight    |    2304    |
# |     layer3.19.dw_bn2.weight     |    256     |
# |      layer3.19.dw_bn2.bias      |    256     |
# |  layer3.19.expand_conv3.weight  |   32768    |
# |   layer3.19.expand_bn3.weight   |    1024    |
# |    layer3.19.expand_bn3.bias    |    1024    |
# | layer3.20.compress_conv1.weight |   262144   |
# |  layer3.20.compress_bn1.weight  |    256     |
# |   layer3.20.compress_bn1.bias   |    256     |
# |    layer3.20.dw_conv2.weight    |    2304    |
# |     layer3.20.dw_bn2.weight     |    256     |
# |      layer3.20.dw_bn2.bias      |    256     |
# |  layer3.20.expand_conv3.weight  |   32768    |
# |   layer3.20.expand_bn3.weight   |    1024    |
# |    layer3.20.expand_bn3.bias    |    1024    |
# | layer3.21.compress_conv1.weight |   262144   |
# |  layer3.21.compress_bn1.weight  |    256     |
# |   layer3.21.compress_bn1.bias   |    256     |
# |    layer3.21.dw_conv2.weight    |    2304    |
# |     layer3.21.dw_bn2.weight     |    256     |
# |      layer3.21.dw_bn2.bias      |    256     |
# |  layer3.21.expand_conv3.weight  |   32768    |
# |   layer3.21.expand_bn3.weight   |    1024    |
# |    layer3.21.expand_bn3.bias    |    1024    |
# | layer3.22.compress_conv1.weight |   262144   |
# |  layer3.22.compress_bn1.weight  |    256     |
# |   layer3.22.compress_bn1.bias   |    256     |
# |    layer3.22.dw_conv2.weight    |    2304    |
# |     layer3.22.dw_bn2.weight     |    256     |
# |      layer3.22.dw_bn2.bias      |    256     |
# |  layer3.22.expand_conv3.weight  |   32768    |
# |   layer3.22.expand_bn3.weight   |    1024    |
# |    layer3.22.expand_bn3.bias    |    1024    |
# |  layer4.0.compress_conv1.weight |   524288   |
# |   layer4.0.compress_bn1.weight  |    512     |
# |    layer4.0.compress_bn1.bias   |    512     |
# |     layer4.0.dw_conv2.weight    |    4608    |
# |      layer4.0.dw_bn2.weight     |    512     |
# |       layer4.0.dw_bn2.bias      |    512     |
# |   layer4.0.expand_conv3.weight  |   65536    |
# |    layer4.0.expand_bn3.weight   |    1024    |
# |     layer4.0.expand_bn3.bias    |    1024    |
# |  layer4.1.compress_conv1.weight |  1048576   |
# |   layer4.1.compress_bn1.weight  |    512     |
# |    layer4.1.compress_bn1.bias   |    512     |
# |     layer4.1.dw_conv2.weight    |    4608    |
# |      layer4.1.dw_bn2.weight     |    512     |
# |       layer4.1.dw_bn2.bias      |    512     |
# |   layer4.1.expand_conv3.weight  |   131072   |
# |    layer4.1.expand_bn3.weight   |    2048    |
# |     layer4.1.expand_bn3.bias    |    2048    |
# |  layer4.2.compress_conv1.weight |  1048576   |
# |   layer4.2.compress_bn1.weight  |    512     |
# |    layer4.2.compress_bn1.bias   |    512     |
# |     layer4.2.dw_conv2.weight    |    4608    |
# |      layer4.2.dw_bn2.weight     |    512     |
# |       layer4.2.dw_bn2.bias      |    512     |
# |   layer4.2.expand_conv3.weight  |   131072   |
# |    layer4.2.expand_bn3.weight   |    2048    |
# |     layer4.2.expand_bn3.bias    |    2048    |
# |            fc.weight            |   20480    |
# |             fc.bias             |     10     |
# +---------------------------------+------------+
# Total Trainable Params: 10077194
# Total Params:  10077194

# %% [markdown]
# # Number of FLOPS

# %%
pip install -U fvcore
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 KB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from fvcore) (1.21.6)
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from fvcore) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from fvcore) (4.64.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.8/dist-packages (from fvcore) (2.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from fvcore) (7.1.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from fvcore) (0.8.10)
# Collecting iopath>=0.1.7
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 KB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.8/dist-packages (from iopath>=0.1.7->fvcore) (4.4.0)
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61431 sha256=98288627eb4edfb5666ae2f6771d6d0d29e16f391aa2c9efb96a91a5fa10dac2
#   Stored in directory: /root/.cache/pip/wheels/b8/79/07/c0e9367f5b5ea325e246bd73651e8af175fabbef943043b1cc
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=73e646f873175d184cbe34988ed61712e7890fcbf466c5fa55826694cec9dabe
#   Stored in directory: /root/.cache/pip/wheels/89/3e/24/0f349c0b2eeb6965903035f3b00dbb5c9bea437b4a2f18d82c
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-2.6.0 yacs-0.1.8

# %%
from fvcore.nn import FlopCountAnalysis
from fvcore.nn import flop_count_table

input =  torch.rand(1, 3, 32, 32)

flops = FlopCountAnalysis(model, input)
print(flop_count_table(flops))
print("Total number of FLOPS: ", flops.total())
# Out:
# | module                      | #parameters or shape   | #flops     |
# |:----------------------------|:-----------------------|:-----------|
# | model                       | 10.077M                | 0.675G     |
# |  conv1                      |  1.728K                |  1.769M    |
# |   conv1.weight              |   (64, 3, 3, 3)        |            |
# |  bn1                        |  0.128K                |  0.131M    |
# |   bn1.weight                |   (64,)                |            |
# |   bn1.bias                  |   (64,)                |            |
# |  layer1                     |  49.088K               |  49.873M   |
# |   layer1.0                  |   9.536K               |   9.634M   |
# |    layer1.0.compress_conv1  |    4.096K              |    4.194M  |
# |    layer1.0.compress_bn1    |    0.128K              |    0.131M  |
# |    layer1.0.dw_conv2        |    0.576K              |    0.59M   |
# |    layer1.0.dw_bn2          |    0.128K              |            |
# |    layer1.0.expand_conv3    |    2.048K              |    2.097M  |
# |    layer1.0.expandConv      |    2.048K              |    2.097M  |
# |    layer1.0.expand_bn3      |    0.512K              |    0.524M  |
# |   layer1.1                  |   19.776K              |   20.12M   |
# |    layer1.1.compress_conv1  |    16.384K             |    16.777M |
# |    layer1.1.compress_bn1    |    0.128K              |    0.131M  |
# |    layer1.1.dw_conv2        |    0.576K              |    0.59M   |
# |    layer1.1.dw_bn2          |    0.128K              |            |
# |    layer1.1.expand_conv3    |    2.048K              |    2.097M  |
# |    layer1.1.expand_bn3      |    0.512K              |    0.524M  |
# |   layer1.2                  |   19.776K              |   20.12M   |
# |    layer1.2.compress_conv1  |    16.384K             |    16.777M |
# |    layer1.2.compress_bn1    |    0.128K              |    0.131M  |
# |    layer1.2.dw_conv2        |    0.576K              |    0.59M   |
# |    layer1.2.dw_bn2          |    0.128K              |            |
# |    layer1.2.expand_conv3    |    2.048K              |    2.097M  |
# |    layer1.2.expand_bn3      |    0.512K              |    0.524M  |
# |  layer2                     |  0.268M                |  93.782M   |
# |   layer2.0                  |   39.04K               |   35.291M  |
# |    layer2.0.compress_conv1  |    32.768K             |    33.554M |
# |    layer2.0.compress_bn1    |    0.256K              |    0.262M  |
# |    layer2.0.dw_conv2        |    1.152K              |    0.295M  |
# |    layer2.0.dw_bn2          |    0.256K              |            |
# |    layer2.0.expand_conv3    |    4.096K              |    1.049M  |
# |    layer2.0.expand_bn3      |    0.512K              |    0.131M  |
# |   layer2.1                  |   76.416K              |   19.497M  |
# |    layer2.1.compress_conv1  |    65.536K             |    16.777M |
# |    layer2.1.compress_bn1    |    0.256K              |    65.536K |
# |    layer2.1.dw_conv2        |    1.152K              |    0.295M  |
# |    layer2.1.dw_bn2          |    0.256K              |            |
# |    layer2.1.expand_conv3    |    8.192K              |    2.097M  |
# |    layer2.1.expand_bn3      |    1.024K              |    0.262M  |
# |   layer2.2                  |   76.416K              |   19.497M  |
# |    layer2.2.compress_conv1  |    65.536K             |    16.777M |
# |    layer2.2.compress_bn1    |    0.256K              |    65.536K |
# |    layer2.2.dw_conv2        |    1.152K              |    0.295M  |
# |    layer2.2.dw_bn2          |    0.256K              |            |
# |    layer2.2.expand_conv3    |    8.192K              |    2.097M  |
# |    layer2.2.expand_bn3      |    1.024K              |    0.262M  |
# |   layer2.3                  |   76.416K              |   19.497M  |
# |    layer2.3.compress_conv1  |    65.536K             |    16.777M |
# |    layer2.3.compress_bn1    |    0.256K              |    65.536K |
# |    layer2.3.dw_conv2        |    1.152K              |    0.295M  |
# |    layer2.3.dw_bn2          |    0.256K              |            |
# |    layer2.3.expand_conv3    |    8.192K              |    2.097M  |
# |    layer2.3.expand_bn3      |    1.024K              |    0.262M  |
# |  layer3                     |  6.758M                |  0.457G    |
# |   layer3.0                  |   0.152M               |   34.947M  |
# |    layer3.0.compress_conv1  |    0.131M              |    33.554M |
# |    layer3.0.compress_bn1    |    0.512K              |    0.131M  |
# |    layer3.0.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.0.dw_bn2          |    0.512K              |            |
# |    layer3.0.expand_conv3    |    16.384K             |    1.049M  |
# |    layer3.0.expand_bn3      |    1.024K              |    65.536K |
# |   layer3.1                  |   0.3M                 |   19.186M  |
# |    layer3.1.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.1.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.1.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.1.dw_bn2          |    0.512K              |            |
# |    layer3.1.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.1.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.2                  |   0.3M                 |   19.186M  |
# |    layer3.2.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.2.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.2.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.2.dw_bn2          |    0.512K              |            |
# |    layer3.2.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.2.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.3                  |   0.3M                 |   19.186M  |
# |    layer3.3.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.3.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.3.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.3.dw_bn2          |    0.512K              |            |
# |    layer3.3.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.3.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.4                  |   0.3M                 |   19.186M  |
# |    layer3.4.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.4.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.4.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.4.dw_bn2          |    0.512K              |            |
# |    layer3.4.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.4.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.5                  |   0.3M                 |   19.186M  |
# |    layer3.5.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.5.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.5.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.5.dw_bn2          |    0.512K              |            |
# |    layer3.5.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.5.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.6                  |   0.3M                 |   19.186M  |
# |    layer3.6.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.6.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.6.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.6.dw_bn2          |    0.512K              |            |
# |    layer3.6.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.6.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.7                  |   0.3M                 |   19.186M  |
# |    layer3.7.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.7.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.7.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.7.dw_bn2          |    0.512K              |            |
# |    layer3.7.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.7.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.8                  |   0.3M                 |   19.186M  |
# |    layer3.8.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.8.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.8.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.8.dw_bn2          |    0.512K              |            |
# |    layer3.8.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.8.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.9                  |   0.3M                 |   19.186M  |
# |    layer3.9.compress_conv1  |    0.262M              |    16.777M |
# |    layer3.9.compress_bn1    |    0.512K              |    32.768K |
# |    layer3.9.dw_conv2        |    2.304K              |    0.147M  |
# |    layer3.9.dw_bn2          |    0.512K              |            |
# |    layer3.9.expand_conv3    |    32.768K             |    2.097M  |
# |    layer3.9.expand_bn3      |    2.048K              |    0.131M  |
# |   layer3.10                 |   0.3M                 |   19.186M  |
# |    layer3.10.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.10.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.10.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.10.dw_bn2         |    0.512K              |            |
# |    layer3.10.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.10.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.11                 |   0.3M                 |   19.186M  |
# |    layer3.11.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.11.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.11.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.11.dw_bn2         |    0.512K              |            |
# |    layer3.11.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.11.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.12                 |   0.3M                 |   19.186M  |
# |    layer3.12.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.12.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.12.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.12.dw_bn2         |    0.512K              |            |
# |    layer3.12.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.12.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.13                 |   0.3M                 |   19.186M  |
# |    layer3.13.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.13.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.13.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.13.dw_bn2         |    0.512K              |            |
# |    layer3.13.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.13.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.14                 |   0.3M                 |   19.186M  |
# |    layer3.14.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.14.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.14.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.14.dw_bn2         |    0.512K              |            |
# |    layer3.14.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.14.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.15                 |   0.3M                 |   19.186M  |
# |    layer3.15.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.15.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.15.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.15.dw_bn2         |    0.512K              |            |
# |    layer3.15.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.15.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.16                 |   0.3M                 |   19.186M  |
# |    layer3.16.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.16.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.16.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.16.dw_bn2         |    0.512K              |            |
# |    layer3.16.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.16.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.17                 |   0.3M                 |   19.186M  |
# |    layer3.17.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.17.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.17.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.17.dw_bn2         |    0.512K              |            |
# |    layer3.17.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.17.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.18                 |   0.3M                 |   19.186M  |
# |    layer3.18.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.18.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.18.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.18.dw_bn2         |    0.512K              |            |
# |    layer3.18.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.18.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.19                 |   0.3M                 |   19.186M  |
# |    layer3.19.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.19.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.19.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.19.dw_bn2         |    0.512K              |            |
# |    layer3.19.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.19.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.20                 |   0.3M                 |   19.186M  |
# |    layer3.20.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.20.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.20.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.20.dw_bn2         |    0.512K              |            |
# |    layer3.20.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.20.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.21                 |   0.3M                 |   19.186M  |
# |    layer3.21.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.21.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.21.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.21.dw_bn2         |    0.512K              |            |
# |    layer3.21.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.21.expand_bn3     |    2.048K              |    0.131M  |
# |   layer3.22                 |   0.3M                 |   19.186M  |
# |    layer3.22.compress_conv1 |    0.262M              |    16.777M |
# |    layer3.22.compress_bn1   |    0.512K              |    32.768K |
# |    layer3.22.dw_conv2       |    2.304K              |    0.147M  |
# |    layer3.22.dw_bn2         |    0.512K              |            |
# |    layer3.22.expand_conv3   |    32.768K             |    2.097M  |
# |    layer3.22.expand_bn3     |    2.048K              |    0.131M  |
# |  layer4                     |  2.979M                |  72.835M   |
# |   layer4.0                  |   0.599M               |   34.775M  |
# |    layer4.0.compress_conv1  |    0.524M              |    33.554M |
# |    layer4.0.compress_bn1    |    1.024K              |    65.536K |
# |    layer4.0.dw_conv2        |    4.608K              |    73.728K |
# |    layer4.0.dw_bn2          |    1.024K              |            |
# |    layer4.0.expand_conv3    |    65.536K             |    1.049M  |
# |    layer4.0.expand_bn3      |    2.048K              |    32.768K |
# |   layer4.1                  |   1.19M                |   19.03M   |
# |    layer4.1.compress_conv1  |    1.049M              |    16.777M |
# |    layer4.1.compress_bn1    |    1.024K              |    16.384K |
# |    layer4.1.dw_conv2        |    4.608K              |    73.728K |
# |    layer4.1.dw_bn2          |    1.024K              |            |
# |    layer4.1.expand_conv3    |    0.131M              |    2.097M  |
# |    layer4.1.expand_bn3      |    4.096K              |    65.536K |
# |   layer4.2                  |   1.19M                |   19.03M   |
# |    layer4.2.compress_conv1  |    1.049M              |    16.777M |
# |    layer4.2.compress_bn1    |    1.024K              |    16.384K |
# |    layer4.2.dw_conv2        |    4.608K              |    73.728K |
# |    layer4.2.dw_bn2          |    1.024K              |            |
# |    layer4.2.expand_conv3    |    0.131M              |    2.097M  |
# |    layer4.2.expand_bn3      |    4.096K              |    65.536K |
# |  fc                         |  20.49K                |  20.48K    |
# |   fc.weight                 |   (10, 2048)           |            |
# |   fc.bias                   |   (10,)                |            |
# |  avgpool                    |                        |  32.768K   |
# Total number of FLOPS:  675475456
