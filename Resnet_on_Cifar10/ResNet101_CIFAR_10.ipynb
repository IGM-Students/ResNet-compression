# %% [markdown]
# # ResNet101 on the CIFAR10 dataset

# %% [markdown]
# ## Import libraries

# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %% [markdown]
# ## Settings

# %%
BATCH_SIZE = 32
EPOCHS = 200
NUM_CLASSES = 10
SUBSTRACT_PIXEL_MEAN = False

N = 11
depth = N * 9 + 2

model_type = 'ResNet%d' % depth

# %% [markdown]
# ## Load the CIFAR10 data

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %% [markdown]
# ## Normalize data and convert class vectors to binary class matrices

# %%
input_shape = x_train.shape[1:]

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

if SUBSTRACT_PIXEL_MEAN:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

y_train = keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test = keras.utils.to_categorical(y_test, NUM_CLASSES)

# %% [markdown]
# ## Learning Rate Schedule

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ## Batch Normalization-Activation-Convolution stack builder for ResNetV2

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %% [markdown]
# ## ResNetV2

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v2(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   272         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   1088        ['activation[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   1088        ['activation_2[0][0]']
#
#  add (Add)                      (None, 32, 32, 64)   0           ['conv2d_4[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['add[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   1040        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   1088        ['activation_5[0][0]']
#
#  add_1 (Add)                    (None, 32, 32, 64)   0           ['add[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['add_1[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   1040        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_8[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['add_1[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 64)  256         ['add_2[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_11[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 64)   0           ['add_2[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['add_3[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_14[0][0]']
#
#  add_4 (Add)                    (None, 32, 32, 64)   0           ['add_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['add_4[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_17[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 64)   0           ['add_4[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  256         ['add_5[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 16)  64          ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 16)  64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_20[0][0]']
#
#  add_6 (Add)                    (None, 32, 32, 64)   0           ['add_5[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 64)  256         ['add_6[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_23[0][0]']
#
#  add_7 (Add)                    (None, 32, 32, 64)   0           ['add_6[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 64)  256         ['add_7[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 16)  64          ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_26[0][0]']
#
#  add_8 (Add)                    (None, 32, 32, 64)   0           ['add_7[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 64)  256         ['add_8[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 16)  64          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_29[0][0]']
#
#  add_9 (Add)                    (None, 32, 32, 64)   0           ['add_8[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 64)  256         ['add_9[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 16)  64          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 16)  64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_32[0][0]']
#
#  add_10 (Add)                   (None, 32, 32, 64)   0           ['add_9[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 64)  256         ['add_10[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 64)   4160        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 128)  8320        ['add_10[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_35[0][0]']
#
#  add_11 (Add)                   (None, 16, 16, 128)  0           ['conv2d_38[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 128)  512        ['add_11[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_38[0][0]']
#
#  add_12 (Add)                   (None, 16, 16, 128)  0           ['add_11[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 128)  512        ['add_12[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_41[0][0]']
#
#  add_13 (Add)                   (None, 16, 16, 128)  0           ['add_12[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 128)  512        ['add_13[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 64)  256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 64)  256         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_44[0][0]']
#
#  add_14 (Add)                   (None, 16, 16, 128)  0           ['add_13[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 128)  512        ['add_14[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 64)  256         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_47[0][0]']
#
#  add_15 (Add)                   (None, 16, 16, 128)  0           ['add_14[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 128)  512        ['add_15[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 16, 16, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 16, 16, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_50[0][0]']
#
#  add_16 (Add)                   (None, 16, 16, 128)  0           ['add_15[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 16, 16, 128)  512        ['add_16[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 16, 16, 64)  256         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 16, 16, 64)  256         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_53[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_53[0][0]']
#
#  add_17 (Add)                   (None, 16, 16, 128)  0           ['add_16[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 128)  512        ['add_17[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 64)  256         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 64)  256         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_56[0][0]']
#
#  add_18 (Add)                   (None, 16, 16, 128)  0           ['add_17[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 16, 16, 128)  512        ['add_18[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 16, 16, 64)  256         ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_58[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 16, 16, 64)  256         ['conv2d_61[0][0]']
#  ormalization)
#
# ...
#                                                                   'conv2d_84[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 256)   1024        ['add_26[0][0]']
#  ormalization)
#
#  activation_81 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 128)    32896       ['activation_81[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 128)   512         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_82[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_82[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 128)   512         ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_83[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 256)    33024       ['activation_83[0][0]']
#
#  add_27 (Add)                   (None, 8, 8, 256)    0           ['add_26[0][0]',
#                                                                   'conv2d_87[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 256)   1024        ['add_27[0][0]']
#  ormalization)
#
#  activation_84 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_84[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 128)    32896       ['activation_84[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 128)   512         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_85[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_85[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 128)   512         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_86[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 256)    33024       ['activation_86[0][0]']
#
#  add_28 (Add)                   (None, 8, 8, 256)    0           ['add_27[0][0]',
#                                                                   'conv2d_90[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 256)   1024        ['add_28[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_87[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 128)    32896       ['activation_87[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 128)   512         ['conv2d_91[0][0]']
#  ormalization)
#
#  activation_88 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_88[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_88[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 128)   512         ['conv2d_92[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 256)    33024       ['activation_89[0][0]']
#
#  add_29 (Add)                   (None, 8, 8, 256)    0           ['add_28[0][0]',
#                                                                   'conv2d_93[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 256)   1024        ['add_29[0][0]']
#  ormalization)
#
#  activation_90 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 128)    32896       ['activation_90[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 128)   512         ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_91 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_91[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_91[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 128)   512         ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_92 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_92[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 256)    33024       ['activation_92[0][0]']
#
#  add_30 (Add)                   (None, 8, 8, 256)    0           ['add_29[0][0]',
#                                                                   'conv2d_96[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 256)   1024        ['add_30[0][0]']
#  ormalization)
#
#  activation_93 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_93[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 8, 8, 128)    32896       ['activation_93[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 128)   512         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_94[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 8, 8, 128)   512         ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_95[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 8, 8, 256)    33024       ['activation_95[0][0]']
#
#  add_31 (Add)                   (None, 8, 8, 256)    0           ['add_30[0][0]',
#                                                                   'conv2d_99[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 8, 8, 256)   1024        ['add_31[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_96[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_96[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 8, 8, 128)   512         ['conv2d_100[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_97[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 8, 8, 128)   512         ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_98[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_98[0][0]']
#
#  add_32 (Add)                   (None, 8, 8, 256)    0           ['add_31[0][0]',
#                                                                   'conv2d_102[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 8, 8, 256)   1024        ['add_32[0][0]']
#  ormalization)
#
#  activation_99 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_99[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 256)   0           ['activation_99[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 256)          0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 10)           2570        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 3,048,298
# Trainable params: 3,029,258
# Non-trainable params: 19,040
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=EPOCHS,
              validation_data=(x_test, y_test),
              shuffle=True,
              # callbacks=callbacks
          )

# %% [markdown]
# ## Score trained model

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
