# %% [markdown]
# # ResNet101 on the CIFAR10 dataset

# %% [markdown]
# ## Import libraries

# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %% [markdown]
# ## Settings

# %%
BATCH_SIZE = 32
EPOCHS = 100
NUM_CLASSES = 10
SUBSTRACT_PIXEL_MEAN = False

N = 11
depth = N * 9 + 2

model_type = 'ResNet%d' % depth

# %% [markdown]
# ## Load the CIFAR10 data

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Normalize data and convert class vectors to binary class matrices

# %%
input_shape = x_train.shape[1:]

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

if SUBSTRACT_PIXEL_MEAN:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

y_train = keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test = keras.utils.to_categorical(y_test, NUM_CLASSES)

# %% [markdown]
# ## Learning Rate Schedule

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ## Batch Normalization-Activation-Convolution stack builder for ResNetV2

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %% [markdown]
# ## ResNetV2

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v2(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_103 (Conv2D)            (None, 32, 32, 16)   448         ['input_2[0][0]']
#
#  batch_normalization_100 (Batch  (None, 32, 32, 16)  64          ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 32, 32, 16)   272         ['activation_100[0][0]']
#
#  batch_normalization_101 (Batch  (None, 32, 32, 16)  64          ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_101[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_101[0][0]']
#
#  batch_normalization_102 (Batch  (None, 32, 32, 16)  64          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_100[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_102[0][0]']
#
#  add_33 (Add)                   (None, 32, 32, 64)   0           ['conv2d_107[0][0]',
#                                                                   'conv2d_106[0][0]']
#
#  batch_normalization_103 (Batch  (None, 32, 32, 64)  256         ['add_33[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_103[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_103[0][0]']
#
#  batch_normalization_104 (Batch  (None, 32, 32, 16)  64          ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_104[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 32, 32, 16)  64          ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_105[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_105[0][0]']
#
#  add_34 (Add)                   (None, 32, 32, 64)   0           ['add_33[0][0]',
#                                                                   'conv2d_110[0][0]']
#
#  batch_normalization_106 (Batch  (None, 32, 32, 64)  256         ['add_34[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_106[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_106[0][0]']
#
#  batch_normalization_107 (Batch  (None, 32, 32, 16)  64          ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_107[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_107[0][0]']
#
#  batch_normalization_108 (Batch  (None, 32, 32, 16)  64          ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_108[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_108[0][0]']
#
#  add_35 (Add)                   (None, 32, 32, 64)   0           ['add_34[0][0]',
#                                                                   'conv2d_113[0][0]']
#
#  batch_normalization_109 (Batch  (None, 32, 32, 64)  256         ['add_35[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 32, 32, 16)  64          ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_110[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_110[0][0]']
#
#  batch_normalization_111 (Batch  (None, 32, 32, 16)  64          ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_111[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_111[0][0]']
#
#  add_36 (Add)                   (None, 32, 32, 64)   0           ['add_35[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  batch_normalization_112 (Batch  (None, 32, 32, 64)  256         ['add_36[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_112[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_112[0][0]']
#
#  batch_normalization_113 (Batch  (None, 32, 32, 16)  64          ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_113[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_113[0][0]']
#
#  batch_normalization_114 (Batch  (None, 32, 32, 16)  64          ['conv2d_118[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_114[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_114[0][0]']
#
#  add_37 (Add)                   (None, 32, 32, 64)   0           ['add_36[0][0]',
#                                                                   'conv2d_119[0][0]']
#
#  batch_normalization_115 (Batch  (None, 32, 32, 64)  256         ['add_37[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_115[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_115[0][0]']
#
#  batch_normalization_116 (Batch  (None, 32, 32, 16)  64          ['conv2d_120[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_116[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_116[0][0]']
#
#  batch_normalization_117 (Batch  (None, 32, 32, 16)  64          ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_117 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_117[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_117[0][0]']
#
#  add_38 (Add)                   (None, 32, 32, 64)   0           ['add_37[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  batch_normalization_118 (Batch  (None, 32, 32, 64)  256         ['add_38[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_118[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 32, 32, 16)  64          ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_119[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_119[0][0]']
#
#  batch_normalization_120 (Batch  (None, 32, 32, 16)  64          ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_120[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_120[0][0]']
#
#  add_39 (Add)                   (None, 32, 32, 64)   0           ['add_38[0][0]',
#                                                                   'conv2d_125[0][0]']
#
#  batch_normalization_121 (Batch  (None, 32, 32, 64)  256         ['add_39[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_121[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 32, 32, 16)  64          ['conv2d_126[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_122[0][0]']
#
#  batch_normalization_123 (Batch  (None, 32, 32, 16)  64          ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_123[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_123[0][0]']
#
#  add_40 (Add)                   (None, 32, 32, 64)   0           ['add_39[0][0]',
#                                                                   'conv2d_128[0][0]']
#
#  batch_normalization_124 (Batch  (None, 32, 32, 64)  256         ['add_40[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_124[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_124[0][0]']
#
#  batch_normalization_125 (Batch  (None, 32, 32, 16)  64          ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_125[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_125[0][0]']
#
#  batch_normalization_126 (Batch  (None, 32, 32, 16)  64          ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_126[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_126[0][0]']
#
#  add_41 (Add)                   (None, 32, 32, 64)   0           ['add_40[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  batch_normalization_127 (Batch  (None, 32, 32, 64)  256         ['add_41[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_127[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_127[0][0]']
#
#  batch_normalization_128 (Batch  (None, 32, 32, 16)  64          ['conv2d_132[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_128[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 32, 32, 16)  64          ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_129[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_129[0][0]']
#
#  add_42 (Add)                   (None, 32, 32, 64)   0           ['add_41[0][0]',
#                                                                   'conv2d_134[0][0]']
#
#  batch_normalization_130 (Batch  (None, 32, 32, 64)  256         ['add_42[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_130[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_130[0][0]']
#
#  batch_normalization_131 (Batch  (None, 32, 32, 16)  64          ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_131[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_131[0][0]']
#
#  batch_normalization_132 (Batch  (None, 32, 32, 16)  64          ['conv2d_136[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_132[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_132[0][0]']
#
#  add_43 (Add)                   (None, 32, 32, 64)   0           ['add_42[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  batch_normalization_133 (Batch  (None, 32, 32, 64)  256         ['add_43[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_133[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 16, 16, 64)   4160        ['activation_133[0][0]']
#
#  batch_normalization_134 (Batch  (None, 16, 16, 64)  256         ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_134[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_134[0][0]']
#
#  batch_normalization_135 (Batch  (None, 16, 16, 64)  256         ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_135[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 16, 16, 128)  8320        ['add_43[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_135[0][0]']
#
#  add_44 (Add)                   (None, 16, 16, 128)  0           ['conv2d_141[0][0]',
#                                                                   'conv2d_140[0][0]']
#
#  batch_normalization_136 (Batch  (None, 16, 16, 128)  512        ['add_44[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_136[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_136[0][0]']
#
#  batch_normalization_137 (Batch  (None, 16, 16, 64)  256         ['conv2d_142[0][0]']
#  Normalization)
#
#  activation_137 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_137[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_137[0][0]']
#
#  batch_normalization_138 (Batch  (None, 16, 16, 64)  256         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_138[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_138[0][0]']
#
#  add_45 (Add)                   (None, 16, 16, 128)  0           ['add_44[0][0]',
#                                                                   'conv2d_144[0][0]']
#
#  batch_normalization_139 (Batch  (None, 16, 16, 128)  512        ['add_45[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_139[0][0]']
#
#  batch_normalization_140 (Batch  (None, 16, 16, 64)  256         ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_140[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_140[0][0]']
#
#  batch_normalization_141 (Batch  (None, 16, 16, 64)  256         ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_141[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_141[0][0]']
#
#  add_46 (Add)                   (None, 16, 16, 128)  0           ['add_45[0][0]',
#                                                                   'conv2d_147[0][0]']
#
#  batch_normalization_142 (Batch  (None, 16, 16, 128)  512        ['add_46[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_142[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_142[0][0]']
#
#  batch_normalization_143 (Batch  (None, 16, 16, 64)  256         ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_143[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_143[0][0]']
#
#  batch_normalization_144 (Batch  (None, 16, 16, 64)  256         ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_144[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_144[0][0]']
#
#  add_47 (Add)                   (None, 16, 16, 128)  0           ['add_46[0][0]',
#                                                                   'conv2d_150[0][0]']
#
#  batch_normalization_145 (Batch  (None, 16, 16, 128)  512        ['add_47[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_145[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 16, 16, 64)  256         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_146[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_146[0][0]']
#
#  batch_normalization_147 (Batch  (None, 16, 16, 64)  256         ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_147[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_147[0][0]']
#
#  add_48 (Add)                   (None, 16, 16, 128)  0           ['add_47[0][0]',
#                                                                   'conv2d_153[0][0]']
#
#  batch_normalization_148 (Batch  (None, 16, 16, 128)  512        ['add_48[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 16, 16, 64)  256         ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_149[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_149[0][0]']
#
#  batch_normalization_150 (Batch  (None, 16, 16, 64)  256         ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_150[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_150[0][0]']
#
#  add_49 (Add)                   (None, 16, 16, 128)  0           ['add_48[0][0]',
#                                                                   'conv2d_156[0][0]']
#
#  batch_normalization_151 (Batch  (None, 16, 16, 128)  512        ['add_49[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_151[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_151[0][0]']
#
#  batch_normalization_152 (Batch  (None, 16, 16, 64)  256         ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_152[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_152[0][0]']
#
#  batch_normalization_153 (Batch  (None, 16, 16, 64)  256         ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_153[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_153[0][0]']
#
#  add_50 (Add)                   (None, 16, 16, 128)  0           ['add_49[0][0]',
#                                                                   'conv2d_159[0][0]']
#
#  batch_normalization_154 (Batch  (None, 16, 16, 128)  512        ['add_50[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_154[0][0]']
#
#  batch_normalization_155 (Batch  (None, 16, 16, 64)  256         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_155[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_155[0][0]']
#
#  batch_normalization_156 (Batch  (None, 16, 16, 64)  256         ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_156[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_156[0][0]']
#
#  add_51 (Add)                   (None, 16, 16, 128)  0           ['add_50[0][0]',
#                                                                   'conv2d_162[0][0]']
#
#  batch_normalization_157 (Batch  (None, 16, 16, 128)  512        ['add_51[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_157[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 16, 16, 64)   8256        ['activation_157[0][0]']
#
#  batch_normalization_158 (Batch  (None, 16, 16, 64)  256         ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_158[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_158[0][0]']
#
#  batch_normalization_159 (Batch  (None, 16, 16, 64)  256         ['conv2d_164[0][0]']
#  Normalization)
#
# ...
#                                                                   'conv2d_187[0][0]']
#
#  batch_normalization_181 (Batch  (None, 8, 8, 256)   1024        ['add_59[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_181[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_181[0][0]']
#
#  batch_normalization_182 (Batch  (None, 8, 8, 128)   512         ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_182 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_182[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_182[0][0]']
#
#  batch_normalization_183 (Batch  (None, 8, 8, 128)   512         ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_183[0][0]']
#
#  add_60 (Add)                   (None, 8, 8, 256)    0           ['add_59[0][0]',
#                                                                   'conv2d_190[0][0]']
#
#  batch_normalization_184 (Batch  (None, 8, 8, 256)   1024        ['add_60[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_184[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_184[0][0]']
#
#  batch_normalization_185 (Batch  (None, 8, 8, 128)   512         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_185[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_185[0][0]']
#
#  batch_normalization_186 (Batch  (None, 8, 8, 128)   512         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_186 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_186[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_186[0][0]']
#
#  add_61 (Add)                   (None, 8, 8, 256)    0           ['add_60[0][0]',
#                                                                   'conv2d_193[0][0]']
#
#  batch_normalization_187 (Batch  (None, 8, 8, 256)   1024        ['add_61[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_187[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_187[0][0]']
#
#  batch_normalization_188 (Batch  (None, 8, 8, 128)   512         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_188[0][0]']
#
#  batch_normalization_189 (Batch  (None, 8, 8, 128)   512         ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_189[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_189[0][0]']
#
#  add_62 (Add)                   (None, 8, 8, 256)    0           ['add_61[0][0]',
#                                                                   'conv2d_196[0][0]']
#
#  batch_normalization_190 (Batch  (None, 8, 8, 256)   1024        ['add_62[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_190[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_190[0][0]']
#
#  batch_normalization_191 (Batch  (None, 8, 8, 128)   512         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_191[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 8, 8, 128)   512         ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_192[0][0]']
#
#  add_63 (Add)                   (None, 8, 8, 256)    0           ['add_62[0][0]',
#                                                                   'conv2d_199[0][0]']
#
#  batch_normalization_193 (Batch  (None, 8, 8, 256)   1024        ['add_63[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_193[0][0]']
#
#  batch_normalization_194 (Batch  (None, 8, 8, 128)   512         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_194[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_194[0][0]']
#
#  batch_normalization_195 (Batch  (None, 8, 8, 128)   512         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_195[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_195[0][0]']
#
#  add_64 (Add)                   (None, 8, 8, 256)    0           ['add_63[0][0]',
#                                                                   'conv2d_202[0][0]']
#
#  batch_normalization_196 (Batch  (None, 8, 8, 256)   1024        ['add_64[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 8, 8, 128)   512         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_197[0][0]']
#
#  batch_normalization_198 (Batch  (None, 8, 8, 128)   512         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_198 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_198[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_198[0][0]']
#
#  add_65 (Add)                   (None, 8, 8, 256)    0           ['add_64[0][0]',
#                                                                   'conv2d_205[0][0]']
#
#  batch_normalization_199 (Batch  (None, 8, 8, 256)   1024        ['add_65[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_199[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 256)   0           ['activation_199[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)            (None, 256)          0           ['average_pooling2d_1[0][0]']
#
#  dense_1 (Dense)                (None, 10)           2570        ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 3,048,298
# Trainable params: 3,029,258
# Non-trainable params: 19,040
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=EPOCHS,
              validation_data=(x_test, y_test),
              shuffle=True,
              # callbacks=callbacks
          )
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 132s 76ms/step - loss: 2.3028 - accuracy: 0.5229 - val_loss: 1.9678 - val_accuracy: 0.5296
# Epoch 2/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 1.4415 - accuracy: 0.6541 - val_loss: 1.5591 - val_accuracy: 0.6010
# Epoch 3/100
# 1563/1563 [==============================] - 121s 77ms/step - loss: 1.2013 - accuracy: 0.7159 - val_loss: 1.8190 - val_accuracy: 0.5158
# Epoch 4/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 1.0738 - accuracy: 0.7521 - val_loss: 1.4164 - val_accuracy: 0.6539
# Epoch 5/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.9777 - accuracy: 0.7774 - val_loss: 1.1582 - val_accuracy: 0.7308
# Epoch 6/100
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.9029 - accuracy: 0.8005 - val_loss: 1.0553 - val_accuracy: 0.7516
# Epoch 7/100
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.8504 - accuracy: 0.8146 - val_loss: 1.1502 - val_accuracy: 0.7001
# Epoch 8/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.8051 - accuracy: 0.8293 - val_loss: 0.9529 - val_accuracy: 0.7746
# Epoch 9/100
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.7713 - accuracy: 0.8398 - val_loss: 1.0386 - val_accuracy: 0.7555
# Epoch 10/100
# 1563/1563 [==============================] - 118s 76ms/step - loss: 0.7318 - accuracy: 0.8530 - val_loss: 1.1659 - val_accuracy: 0.7400
# Epoch 11/100
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.7115 - accuracy: 0.8586 - val_loss: 1.0846 - val_accuracy: 0.7506
# Epoch 12/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.6862 - accuracy: 0.8675 - val_loss: 1.0202 - val_accuracy: 0.7774
# Epoch 13/100
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.6635 - accuracy: 0.8764 - val_loss: 0.9672 - val_accuracy: 0.7811
# Epoch 14/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.6484 - accuracy: 0.8803 - val_loss: 1.4973 - val_accuracy: 0.7020
# Epoch 15/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.6367 - accuracy: 0.8833 - val_loss: 1.0600 - val_accuracy: 0.7720
# Epoch 16/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.6160 - accuracy: 0.8921 - val_loss: 1.1523 - val_accuracy: 0.7496
# Epoch 17/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.6109 - accuracy: 0.8952 - val_loss: 0.8960 - val_accuracy: 0.8175
# Epoch 18/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5979 - accuracy: 0.8999 - val_loss: 1.2561 - val_accuracy: 0.7255
# Epoch 19/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5892 - accuracy: 0.9030 - val_loss: 1.1803 - val_accuracy: 0.7465
# Epoch 20/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5828 - accuracy: 0.9054 - val_loss: 1.2838 - val_accuracy: 0.7263
# Epoch 21/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5716 - accuracy: 0.9094 - val_loss: 1.0810 - val_accuracy: 0.7733
# Epoch 22/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5654 - accuracy: 0.9126 - val_loss: 0.9890 - val_accuracy: 0.7912
# Epoch 23/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5648 - accuracy: 0.9129 - val_loss: 1.2023 - val_accuracy: 0.7682
# Epoch 24/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5561 - accuracy: 0.9171 - val_loss: 1.3399 - val_accuracy: 0.7254
# Epoch 25/100
# 1563/1563 [==============================] - 116s 75ms/step - loss: 0.5498 - accuracy: 0.9192 - val_loss: 1.1469 - val_accuracy: 0.7668
# Epoch 26/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5465 - accuracy: 0.9204 - val_loss: 1.0242 - val_accuracy: 0.7973
# Epoch 27/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5412 - accuracy: 0.9228 - val_loss: 1.4541 - val_accuracy: 0.7147
# Epoch 28/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5367 - accuracy: 0.9250 - val_loss: 1.1708 - val_accuracy: 0.7668
# Epoch 29/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.5353 - accuracy: 0.9237 - val_loss: 1.1580 - val_accuracy: 0.7552
# Epoch 30/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5314 - accuracy: 0.9257 - val_loss: 1.1400 - val_accuracy: 0.7645
# Epoch 31/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5325 - accuracy: 0.9261 - val_loss: 1.0702 - val_accuracy: 0.7848
# Epoch 32/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5287 - accuracy: 0.9279 - val_loss: 1.0095 - val_accuracy: 0.8073
# Epoch 33/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5228 - accuracy: 0.9304 - val_loss: 0.9503 - val_accuracy: 0.8201
# Epoch 34/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5190 - accuracy: 0.9310 - val_loss: 1.0130 - val_accuracy: 0.8022
# Epoch 35/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5234 - accuracy: 0.9279 - val_loss: 0.9357 - val_accuracy: 0.8235
# Epoch 36/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5149 - accuracy: 0.9318 - val_loss: 1.5164 - val_accuracy: 0.7141
# Epoch 37/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5139 - accuracy: 0.9313 - val_loss: 1.3324 - val_accuracy: 0.7502
# Epoch 38/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5134 - accuracy: 0.9319 - val_loss: 1.1024 - val_accuracy: 0.7889
# Epoch 39/100
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5063 - accuracy: 0.9338 - val_loss: 0.9704 - val_accuracy: 0.8131
# Epoch 40/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.5018 - accuracy: 0.9351 - val_loss: 0.9679 - val_accuracy: 0.8183
# Epoch 41/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.5033 - accuracy: 0.9350 - val_loss: 1.1421 - val_accuracy: 0.7943
# Epoch 42/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.5052 - accuracy: 0.9338 - val_loss: 1.3024 - val_accuracy: 0.7527
# Epoch 43/100
# 1563/1563 [==============================] - 113s 73ms/step - loss: 0.4936 - accuracy: 0.9374 - val_loss: 1.0719 - val_accuracy: 0.7898
# Epoch 44/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.5019 - accuracy: 0.9341 - val_loss: 0.9641 - val_accuracy: 0.8101
# Epoch 45/100
# 1563/1563 [==============================] - 118s 76ms/step - loss: 0.4913 - accuracy: 0.9377 - val_loss: 1.1227 - val_accuracy: 0.7809
# Epoch 46/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4897 - accuracy: 0.9376 - val_loss: 1.1006 - val_accuracy: 0.8006
# Epoch 47/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 0.4876 - accuracy: 0.9383 - val_loss: 1.3333 - val_accuracy: 0.7423
# Epoch 48/100
# 1563/1563 [==============================] - 115s 74ms/step - loss: 0.4898 - accuracy: 0.9366 - val_loss: 1.1040 - val_accuracy: 0.7964
# Epoch 49/100
# 1563/1563 [==============================] - 115s 74ms/step - loss: 0.4861 - accuracy: 0.9390 - val_loss: 1.2226 - val_accuracy: 0.7653
# Epoch 50/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4846 - accuracy: 0.9388 - val_loss: 1.2345 - val_accuracy: 0.7598
# Epoch 51/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 0.4842 - accuracy: 0.9377 - val_loss: 1.0524 - val_accuracy: 0.8005
# Epoch 52/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.4830 - accuracy: 0.9381 - val_loss: 1.0767 - val_accuracy: 0.7971
# Epoch 53/100
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.4798 - accuracy: 0.9385 - val_loss: 1.3992 - val_accuracy: 0.7515
# Epoch 54/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4776 - accuracy: 0.9406 - val_loss: 1.0420 - val_accuracy: 0.8063
# Epoch 55/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4756 - accuracy: 0.9417 - val_loss: 0.9356 - val_accuracy: 0.8177
# Epoch 56/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.4744 - accuracy: 0.9418 - val_loss: 1.0013 - val_accuracy: 0.8084
# Epoch 57/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4725 - accuracy: 0.9415 - val_loss: 1.0291 - val_accuracy: 0.8085
# Epoch 58/100
# 1563/1563 [==============================] - 113s 73ms/step - loss: 0.4703 - accuracy: 0.9420 - val_loss: 1.0311 - val_accuracy: 0.8088
# Epoch 59/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4695 - accuracy: 0.9424 - val_loss: 1.0275 - val_accuracy: 0.7992
# Epoch 60/100
# 1563/1563 [==============================] - 113s 73ms/step - loss: 0.4701 - accuracy: 0.9418 - val_loss: 0.9957 - val_accuracy: 0.8054
# Epoch 61/100
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.4663 - accuracy: 0.9431 - val_loss: 1.4416 - val_accuracy: 0.7276
# Epoch 62/100
# 1563/1563 [==============================] - 113s 73ms/step - loss: 0.4617 - accuracy: 0.9440 - val_loss: 0.9295 - val_accuracy: 0.8271
# Epoch 63/100
# 1563/1563 [==============================] - 118s 76ms/step - loss: 0.4673 - accuracy: 0.9419 - val_loss: 1.0671 - val_accuracy: 0.7958
# Epoch 64/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4627 - accuracy: 0.9439 - val_loss: 0.9571 - val_accuracy: 0.8234
# Epoch 65/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4565 - accuracy: 0.9456 - val_loss: 0.9561 - val_accuracy: 0.8189
# Epoch 66/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4620 - accuracy: 0.9427 - val_loss: 0.9425 - val_accuracy: 0.8125
# Epoch 67/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 0.4528 - accuracy: 0.9457 - val_loss: 1.1592 - val_accuracy: 0.7989
# Epoch 68/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4619 - accuracy: 0.9425 - val_loss: 1.2010 - val_accuracy: 0.7775
# Epoch 69/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4554 - accuracy: 0.9442 - val_loss: 1.0198 - val_accuracy: 0.8016
# Epoch 70/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4496 - accuracy: 0.9465 - val_loss: 1.0616 - val_accuracy: 0.8066
# Epoch 71/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4573 - accuracy: 0.9431 - val_loss: 1.3064 - val_accuracy: 0.7534
# Epoch 72/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.4466 - accuracy: 0.9469 - val_loss: 1.1333 - val_accuracy: 0.7883
# Epoch 73/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4509 - accuracy: 0.9449 - val_loss: 1.0501 - val_accuracy: 0.8024
# Epoch 74/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4481 - accuracy: 0.9473 - val_loss: 1.0363 - val_accuracy: 0.8003
# Epoch 75/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 0.4470 - accuracy: 0.9466 - val_loss: 0.9448 - val_accuracy: 0.8191
# Epoch 76/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4421 - accuracy: 0.9473 - val_loss: 1.0467 - val_accuracy: 0.7977
# Epoch 77/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.4477 - accuracy: 0.9457 - val_loss: 1.4056 - val_accuracy: 0.7503
# Epoch 78/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4451 - accuracy: 0.9459 - val_loss: 1.1045 - val_accuracy: 0.7983
# Epoch 79/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4409 - accuracy: 0.9457 - val_loss: 1.4770 - val_accuracy: 0.7368
# Epoch 80/100
# 1563/1563 [==============================] - 118s 76ms/step - loss: 0.4423 - accuracy: 0.9467 - val_loss: 0.9936 - val_accuracy: 0.8129
# Epoch 81/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4412 - accuracy: 0.9462 - val_loss: 1.1679 - val_accuracy: 0.7787
# Epoch 82/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4376 - accuracy: 0.9475 - val_loss: 0.9649 - val_accuracy: 0.8191
# Epoch 83/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4409 - accuracy: 0.9461 - val_loss: 1.2103 - val_accuracy: 0.7613
# Epoch 84/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 0.4359 - accuracy: 0.9481 - val_loss: 1.1424 - val_accuracy: 0.7945
# Epoch 85/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4312 - accuracy: 0.9491 - val_loss: 0.9639 - val_accuracy: 0.8220
# Epoch 86/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4347 - accuracy: 0.9472 - val_loss: 1.4610 - val_accuracy: 0.7516
# Epoch 87/100
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.4387 - accuracy: 0.9448 - val_loss: 1.1114 - val_accuracy: 0.7875
# Epoch 88/100
# 1563/1563 [==============================] - 115s 74ms/step - loss: 0.4297 - accuracy: 0.9495 - val_loss: 1.1725 - val_accuracy: 0.7964
# Epoch 89/100
# 1563/1563 [==============================] - 113s 73ms/step - loss: 0.4309 - accuracy: 0.9489 - val_loss: 1.0173 - val_accuracy: 0.7999
# Epoch 90/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.4227 - accuracy: 0.9508 - val_loss: 0.9593 - val_accuracy: 0.8223
# Epoch 91/100
# 1563/1563 [==============================] - 118s 76ms/step - loss: 0.4299 - accuracy: 0.9471 - val_loss: 1.1661 - val_accuracy: 0.7859
# Epoch 92/100
# 1563/1563 [==============================] - 115s 74ms/step - loss: 0.4291 - accuracy: 0.9478 - val_loss: 1.1952 - val_accuracy: 0.7819
# Epoch 93/100
# 1563/1563 [==============================] - 115s 74ms/step - loss: 0.4279 - accuracy: 0.9481 - val_loss: 1.0742 - val_accuracy: 0.8019
# Epoch 94/100
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.4230 - accuracy: 0.9494 - val_loss: 0.9396 - val_accuracy: 0.8239
# Epoch 95/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4227 - accuracy: 0.9497 - val_loss: 1.1128 - val_accuracy: 0.8043
# Epoch 96/100
# 1563/1563 [==============================] - 113s 73ms/step - loss: 0.4169 - accuracy: 0.9505 - val_loss: 1.0059 - val_accuracy: 0.8226
# Epoch 97/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4216 - accuracy: 0.9497 - val_loss: 1.0178 - val_accuracy: 0.8081
# Epoch 98/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4241 - accuracy: 0.9484 - val_loss: 0.9006 - val_accuracy: 0.8215
# Epoch 99/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.4151 - accuracy: 0.9508 - val_loss: 1.0858 - val_accuracy: 0.8000
# Epoch 100/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.4213 - accuracy: 0.9488 - val_loss: 1.3245 - val_accuracy: 0.7551

# %% [markdown]
# ## Score trained model

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 313/313 [==============================] - 7s 22ms/step - loss: 1.3245 - accuracy: 0.7551
# Test loss: 1.3245182037353516
# Test accuracy: 0.7551000118255615

# %%
model.save("./ResNet101.h5")
